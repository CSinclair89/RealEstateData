# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pd2 = pd.read_csv("week6gss.csv", engine = "python")
pd2
# Out:
#        year   id_               hrs2 childs             income  \
# 0      1972     1  .i:  Inapplicable      0  .i:  Inapplicable
# 1      1972     2  .i:  Inapplicable      5  .i:  Inapplicable
# 2      1972     3  .i:  Inapplicable      4  .i:  Inapplicable
# 3      1972     4  .i:  Inapplicable      0  .i:  Inapplicable
# 4      1972     5  .i:  Inapplicable      2  .i:  Inapplicable
# ...     ...   ...                ...    ...                ...
# 68841  2021  4467  .i:  Inapplicable      0   $8,000 to $9,999
# 68842  2021  4468                 50      2    $25,000 or more
# 68843  2021  4469  .i:  Inapplicable      2    $25,000 or more
# 68844  2021  4470  .i:  Inapplicable      2   $1,000 to $2,999
# 68845  2021  4471  .i:  Inapplicable      1    $25,000 or more
#
#                            attend
# 0      About once or twice a year
# 1                      Every week
# 2              About once a month
# 3                           Never
# 4                           Never
# ...                           ...
# 68841  About once or twice a year
# 68842                  Every week
# 68843  About once or twice a year
# 68844       Less than once a year
# 68845           2-3 times a month
#
# [68846 rows x 6 columns]

# %%
pd2 = pd2[pd2["year"] == 1989]
pd2
# Out:
#        year   id_ hrs2 childs   income                      attend
# 24602  1989  1247   10      3  25000.0                  Every week
# 24032  1989   677   10      3  10000.0        Several times a week
# 23969  1989   614   15      4  10000.0  About once or twice a year
# 23997  1989   642   17      2  10000.0  About once or twice a year
# 24838  1989  1483   24      2  25000.0        Several times a week
# 24097  1989   742   30      0   7000.0                       Never
# 24665  1989  1310   32      3  25000.0           2-3 times a month
# 24187  1989   832   35      0  10000.0           Nearly every week
# 23544  1989   189   35      0  25000.0  About once or twice a year
# 24561  1989  1206   38      2  20000.0          About once a month
# 23810  1989   455   38      2  25000.0                  Every week
# 24416  1989  1061   40      2  25000.0          About once a month
# 24818  1989  1463   40      4  25000.0           Nearly every week
# 23579  1989   224   40      2  25000.0        Several times a year
# 24068  1989   713   40      1  25000.0          About once a month
# 24376  1989  1021   40      0  25000.0           Nearly every week
# 24283  1989   928   40      1   5000.0        Several times a week
# 23715  1989   360   40      2  25000.0       Less than once a year
# 23710  1989   355   40      1  25000.0                  Every week
# 23401  1989    46   40      2  20000.0          About once a month
# 24827  1989  1472   40      2  20000.0                  Every week
# 23775  1989   420   40      5  20000.0                  Every week
# 23879  1989   524   42      0  25000.0                  Every week
# 23584  1989   229   43      0  25000.0       Less than once a year
# 23523  1989   168   43      0  25000.0           Nearly every week
# 23942  1989   587   45      0  25000.0  About once or twice a year
# 24748  1989  1393   48      3  10000.0          About once a month
# 24855  1989  1500   50      0  20000.0                  Every week
# 24269  1989   914   50      2  25000.0          About once a month
# 24831  1989  1476   50      2  25000.0                       Never
# 23438  1989    83   50      1  25000.0  About once or twice a year
# 24413  1989  1058   55      3  25000.0                       Never
# 24041  1989   686   58      0  25000.0                  Every week
# 23672  1989   317   60      0  25000.0  About once or twice a year
# 23893  1989   538   65      0  25000.0        Several times a year
# 24261  1989   906   68      2  25000.0       Less than once a year
# 23601  1989   246   84      0  25000.0        Several times a year

# %%
pd2.dtypes
# Out:
# year        int64
# id_         int64
# hrs2       object
# childs     object
# income    float64
# attend     object
# dtype: object

# %%
pd2 = pd2[~pd2["hrs2"].str.contains("Inapplicable", "No answer")]
pd2["hrs2"] = pd2["hrs2"].astype(float)
pd2 = pd2.sort_values(by = ["hrs2"])
pd2
# Out:
#        year   id_  hrs2 childs   income                      attend
# 24602  1989  1247  10.0      3  25000.0                  Every week
# 24032  1989   677  10.0      3  10000.0        Several times a week
# 23969  1989   614  15.0      4  10000.0  About once or twice a year
# 23997  1989   642  17.0      2  10000.0  About once or twice a year
# 24838  1989  1483  24.0      2  25000.0        Several times a week
# 24097  1989   742  30.0      0   7000.0                       Never
# 24665  1989  1310  32.0      3  25000.0           2-3 times a month
# 24187  1989   832  35.0      0  10000.0           Nearly every week
# 23544  1989   189  35.0      0  25000.0  About once or twice a year
# 24561  1989  1206  38.0      2  20000.0          About once a month
# 23810  1989   455  38.0      2  25000.0                  Every week
# 24416  1989  1061  40.0      2  25000.0          About once a month
# 24818  1989  1463  40.0      4  25000.0           Nearly every week
# 23579  1989   224  40.0      2  25000.0        Several times a year
# 24068  1989   713  40.0      1  25000.0          About once a month
# 24283  1989   928  40.0      1   5000.0        Several times a week
# 23710  1989   355  40.0      1  25000.0                  Every week
# 23715  1989   360  40.0      2  25000.0       Less than once a year
# 24376  1989  1021  40.0      0  25000.0           Nearly every week
# 23401  1989    46  40.0      2  20000.0          About once a month
# 24827  1989  1472  40.0      2  20000.0                  Every week
# 23775  1989   420  40.0      5  20000.0                  Every week
# 23879  1989   524  42.0      0  25000.0                  Every week
# 23584  1989   229  43.0      0  25000.0       Less than once a year
# 23523  1989   168  43.0      0  25000.0           Nearly every week
# 23942  1989   587  45.0      0  25000.0  About once or twice a year
# 24748  1989  1393  48.0      3  10000.0          About once a month
# 24855  1989  1500  50.0      0  20000.0                  Every week
# 24269  1989   914  50.0      2  25000.0          About once a month
# 24831  1989  1476  50.0      2  25000.0                       Never
# 23438  1989    83  50.0      1  25000.0  About once or twice a year
# 24413  1989  1058  55.0      3  25000.0                       Never
# 24041  1989   686  58.0      0  25000.0                  Every week
# 23672  1989   317  60.0      0  25000.0  About once or twice a year
# 23893  1989   538  65.0      0  25000.0        Several times a year
# 24261  1989   906  68.0      2  25000.0       Less than once a year
# 23601  1989   246  84.0      0  25000.0        Several times a year

# %%
pd2 = pd2[~pd2["income"].str.contains("Do not Know")]
pd2 = pd2[~pd2["income"].str.contains("Refused")]
pd2[['income']] = pd2[['income']].replace('[\$,]','',regex=True)
pd2[['income']] = pd2[['income']].replace('5000 to 5999','5000',regex=True)
pd2[['income']] = pd2[['income']].replace('7000 to 7999','7000',regex=True)
pd2[['income']] = pd2[['income']].replace('10000 to 14999','10000',regex=True)
pd2[['income']] = pd2[['income']].replace('20000 to 24999','20000',regex=True)
pd2[['income']] = pd2[['income']].replace('25000 to mtoe','25000',regex=True)
pd2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8804\4006655010.py in <module>
# ----> 1 pd2 = pd2[~pd2["income"].str.contains("Do not Know")]
#       2 pd2 = pd2[~pd2["income"].str.contains("Refused")]
#       3 pd2[['income']] = pd2[['income']].replace('[\$,]','',regex=True)
#       4 pd2[['income']] = pd2[['income']].replace('5000 to 5999','5000',regex=True)
#       5 pd2[['income']] = pd2[['income']].replace('7000 to 7999','7000',regex=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
pd2_x = pd2["hrs2"]
pd2_y = pd2["income"]
plt.scatter(pd2_x, pd2_y)
plt.xlabel("Hours worked")
plt.ylabel("Income")
plt.show()

# %%
pd2_r = np.corrcoef(pd2_x, pd2_y)
pd2_r
# Out:
# array([[1.        , 0.42615433],
#        [0.42615433, 1.        ]])

# %%
pd2_r2 = 0.42615433 ** 2
pd2_r2
# Out:
# 0.1816075129777489

# %%
pd2_subset = pd2[["childs", "attend"]]
pd2_subset
# Out:
#       childs                      attend
# 24602      3                  Every week
# 24032      3        Several times a week
# 23969      4  About once or twice a year
# 23997      2  About once or twice a year
# 24838      2        Several times a week
# 24097      0                       Never
# 24665      3           2-3 times a month
# 24187      0           Nearly every week
# 23544      0  About once or twice a year
# 24561      2          About once a month
# 23810      2                  Every week
# 24416      2          About once a month
# 24818      4           Nearly every week
# 23579      2        Several times a year
# 24068      1          About once a month
# 24283      1        Several times a week
# 23710      1                  Every week
# 23715      2       Less than once a year
# 24376      0           Nearly every week
# 23401      2          About once a month
# 24827      2                  Every week
# 23775      5                  Every week
# 23879      0                  Every week
# 23584      0       Less than once a year
# 23523      0           Nearly every week
# 23942      0  About once or twice a year
# 24748      3          About once a month
# 24855      0                  Every week
# 24269      2          About once a month
# 24831      2                       Never
# 23438      1  About once or twice a year
# 24413      3                       Never
# 24041      0                  Every week
# 23672      0  About once or twice a year
# 23893      0        Several times a year
# 24261      2       Less than once a year
# 23601      0        Several times a year

# %%
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Never','0',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Less than once a year','1',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('About once or twice a year','2',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Several times a year','3',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('About once a month','4',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('2-3 times a month','5',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Nearly every week','6',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Every week','7',regex=True)
pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Several times a week','8',regex=True)
pd2_subset["attend"] = pd2_subset["attend"].astype(float)
pd2_subset["childs"] = pd2_subset["childs"].astype(float)
pd2_subset
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Never','0',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Less than once a year','1',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('About once or twice a year','2',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Several times a year','3',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('About once a month','4',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('2-3 times a month','5',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Nearly every week','6',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Every week','7',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset[["attend"]] = pd2_subset[["attend"]].replace('Several times a week','8',regex=True)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset["attend"] = pd2_subset["attend"].astype(float)
# C:\Users\Chris\AppData\Local\Temp\ipykernel_8804\1990405898.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd2_subset["childs"] = pd2_subset["childs"].astype(float)
#        childs  attend
# 24602     3.0     7.0
# 24032     3.0     8.0
# 23969     4.0     2.0
# 23997     2.0     2.0
# 24838     2.0     8.0
# 24097     0.0     0.0
# 24665     3.0     5.0
# 24187     0.0     6.0
# 23544     0.0     2.0
# 24561     2.0     4.0
# 23810     2.0     7.0
# 24416     2.0     4.0
# 24818     4.0     6.0
# 23579     2.0     3.0
# 24068     1.0     4.0
# 24283     1.0     8.0
# 23710     1.0     7.0
# 23715     2.0     1.0
# 24376     0.0     6.0
# 23401     2.0     4.0
# 24827     2.0     7.0
# 23775     5.0     7.0
# 23879     0.0     7.0
# 23584     0.0     1.0
# 23523     0.0     6.0
# 23942     0.0     2.0
# 24748     3.0     4.0
# 24855     0.0     7.0
# 24269     2.0     4.0
# 24831     2.0     0.0
# 23438     1.0     2.0
# 24413     3.0     0.0
# 24041     0.0     7.0
# 23672     0.0     2.0
# 23893     0.0     3.0
# 24261     2.0     1.0
# 23601     0.0     3.0

# %%
pd2_t2x = pd2_subset["attend"]
pd2_t2y = pd2_subset["childs"]
plt.scatter(pd2_t2x, pd2_t2y)
plt.xlabel("How often they attend religious service?")
plt.ylabel("No. of Children")
plt.show()

# %%
pd2_t2r = np.corrcoef(pd2_t2x, pd2_t2y)
pd2_t2r
# Out:
# array([[1.        , 0.09666612],
#        [0.09666612, 1.        ]])

# %%
pd2_t2r2 = 0.09666612 ** 2
pd2_t2r2
# Out:
# 0.009344338755854399
